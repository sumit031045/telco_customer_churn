# %%
import pandas as pd

# %%
df = pd.read_csv("Telco_Customer_Churn_Dataset  (3).csv")

# %%
df['tenure_group'] = pd.cut(df['tenure'], 
bins=[0,12,24,48,72], 
labels=['0-1 year','1-2 years','2-4 years','4-6 years'])

# %%
df['charges_group'] = pd.cut(df['MonthlyCharges'],
 bins=[0,35,70,120],
labels=['low','Medium','High'])

# %%
df['Contract'] = df['Contract'].str.strip()

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True) * 100
# Out:
# Contract        Churn
# Month-to-month  No       57.290323
#                 Yes      42.709677
# One year        No       88.730482
#                 Yes      11.269518
# Two year        No       97.168142
#                 Yes       2.831858
# Name: proportion, dtype: float64

# %%
high_risk = df[
    (df['tenure'] < 12) &
    (df['MonthlyCharges'] > 70) &
    (df['Contract'] == 'Month-to-month')
]

# %%
high_risk.shape
# Out:
# (814, 23)

# %%
high_risk[['tenure', 'MonthlyCharges', 'Contract', 'Churn']].head()
# Out:
#     tenure  MonthlyCharges        Contract Churn
# 4        2           70.70  Month-to-month   Yes
# 5        8           99.65  Month-to-month   Yes
# 31       2           95.50  Month-to-month    No
# 39      11           97.85  Month-to-month   Yes
# 47       2           80.65  Month-to-month   Yes

# %%
high_risk['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# Yes    69.53317
# No     30.46683
# Name: proportion, dtype: float64
